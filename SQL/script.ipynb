-- %% [markdown]
-- # [RetailNetwork]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [RetailNetwork]    Script Date: 20.02.2026 18:39:42 ******/
CREATE DATABASE [RetailNetwork]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'RetailNetwork', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.MSSQLSERVER\MSSQL\DATA\RetailNetwork.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'RetailNetwork_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.MSSQLSERVER\MSSQL\DATA\RetailNetwork_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [RetailNetwork] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [RetailNetwork].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [RetailNetwork] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [RetailNetwork] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [RetailNetwork] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [RetailNetwork] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [RetailNetwork] SET ARITHABORT OFF 
GO
ALTER DATABASE [RetailNetwork] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [RetailNetwork] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [RetailNetwork] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [RetailNetwork] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [RetailNetwork] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [RetailNetwork] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [RetailNetwork] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [RetailNetwork] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [RetailNetwork] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [RetailNetwork] SET  ENABLE_BROKER 
GO
ALTER DATABASE [RetailNetwork] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [RetailNetwork] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [RetailNetwork] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [RetailNetwork] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [RetailNetwork] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [RetailNetwork] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [RetailNetwork] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [RetailNetwork] SET RECOVERY FULL 
GO
ALTER DATABASE [RetailNetwork] SET  MULTI_USER 
GO
ALTER DATABASE [RetailNetwork] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [RetailNetwork] SET DB_CHAINING OFF 
GO
ALTER DATABASE [RetailNetwork] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [RetailNetwork] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [RetailNetwork] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [RetailNetwork] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
EXEC sys.sp_db_vardecimal_storage_format N'RetailNetwork', N'ON'
GO
ALTER DATABASE [RetailNetwork] SET QUERY_STORE = ON
GO
ALTER DATABASE [RetailNetwork] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[ContactInfo]

-- %%
USE [RetailNetwork]
GO

-- %%
/****** Object:  Table [dbo].[ContactInfo]    Script Date: 20.02.2026 18:39:43 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ContactInfo](
	[SellerID] [int] NOT NULL,
	[Phone] [nvarchar](20) NOT NULL,
	[Email] [nvarchar](100) NULL,
	[Address] [nvarchar](500) NULL,
PRIMARY KEY CLUSTERED 
(
	[SellerID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Receipts]

-- %%
/****** Object:  Table [dbo].[Receipts]    Script Date: 20.02.2026 18:39:43 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Receipts](
	[ReceiptID] [uniqueidentifier] NOT NULL,
	[ReceiptNumber] [nvarchar](50) NOT NULL,
	[ShopID] [int] NOT NULL,
	[SellerID] [int] NOT NULL,
	[TotalAmount] [decimal](10, 2) NOT NULL,
	[SaleDate] [datetime2](7) NULL,
	[PaymentType] [nvarchar](30) NULL,
PRIMARY KEY CLUSTERED 
(
	[ReceiptID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Reviews]

-- %%
/****** Object:  Table [dbo].[Reviews]    Script Date: 20.02.2026 18:39:43 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Reviews](
	[ReviewID] [uniqueidentifier] NOT NULL,
	[ShopID] [int] NOT NULL,
	[CustomerName] [nvarchar](200) NOT NULL,
	[Rating] [int] NOT NULL,
	[Comment] [nvarchar](max) NULL,
	[ReviewDate] [datetime2](7) NULL,
PRIMARY KEY CLUSTERED 
(
	[ReviewID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Sellers]

-- %%
/****** Object:  Table [dbo].[Sellers]    Script Date: 20.02.2026 18:39:43 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Sellers](
	[SellerID] [int] IDENTITY(1,1) NOT NULL,
	[LastName] [nvarchar](100) NOT NULL,
	[FirstName] [nvarchar](100) NOT NULL,
	[Patronymic] [nvarchar](100) NULL,
	[BirthDate] [date] NOT NULL,
	[IsActive] [bit] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[SellerID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Shops]

-- %%
/****** Object:  Table [dbo].[Shops]    Script Date: 20.02.2026 18:39:43 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Shops](
	[ShopID] [int] IDENTITY(1,1) NOT NULL,
	[ShopName] [nvarchar](200) NOT NULL,
	[Address] [nvarchar](500) NOT NULL,
	[Phone] [nvarchar](20) NULL,
PRIMARY KEY CLUSTERED 
(
	[ShopID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ShopSellers]

-- %%
/****** Object:  Table [dbo].[ShopSellers]    Script Date: 20.02.2026 18:39:43 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ShopSellers](
	[ShopID] [int] NOT NULL,
	[SellerID] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[ShopID] ASC,
	[SellerID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ContactInfo]

-- %%
INSERT [dbo].[ContactInfo] ([SellerID], [Phone], [Email], [Address]) VALUES (1, N'89345678123', N'a@dmail.com', NULL)
INSERT [dbo].[ContactInfo] ([SellerID], [Phone], [Email], [Address]) VALUES (3, N'+79998887766', N'new6email@mail.ru', NULL)
INSERT [dbo].[ContactInfo] ([SellerID], [Phone], [Email], [Address]) VALUES (6, N'89004278456', N'igor@mail.ru', N'г. Киров, ул. Ленина, 111, кв. 21')
GO

-- %% [markdown]
-- # [dbo].[Receipts]

-- %%
INSERT [dbo].[Receipts] ([ReceiptID], [ReceiptNumber], [ShopID], [SellerID], [TotalAmount], [SaleDate], [PaymentType]) VALUES (N'e768d6e7-5089-45a6-a5b2-1f7594486304', N'1', 1, 1, CAST(6780.00 AS Decimal(10, 2)), CAST(N'2024-01-25T23:00:00.0000000' AS DateTime2), N'Cash')
INSERT [dbo].[Receipts] ([ReceiptID], [ReceiptNumber], [ShopID], [SellerID], [TotalAmount], [SaleDate], [PaymentType]) VALUES (N'90f69733-ed1b-4a54-a890-4ab63e988001', N'3', 3, 6, CAST(3079.80 AS Decimal(10, 2)), CAST(N'2023-10-12T09:10:00.0000000' AS DateTime2), N'Card')
INSERT [dbo].[Receipts] ([ReceiptID], [ReceiptNumber], [ShopID], [SellerID], [TotalAmount], [SaleDate], [PaymentType]) VALUES (N'c4adc069-7de2-4b57-97d7-74500877889e', N'2', 1, 3, CAST(30.60 AS Decimal(10, 2)), CAST(N'2023-09-09T12:34:12.0000000' AS DateTime2), N'Cash')
GO

-- %% [markdown]
-- # [dbo].[Reviews]

-- %%
INSERT [dbo].[Reviews] ([ReviewID], [ShopID], [CustomerName], [Rating], [Comment], [ReviewDate]) VALUES (N'8e0a4ab5-ce34-4095-9625-6be4b856e999', 2, N'hao lin', 3, N'ну средне, персонал так себе', CAST(N'2025-09-08T17:07:07.0000000' AS DateTime2))
INSERT [dbo].[Reviews] ([ReviewID], [ShopID], [CustomerName], [Rating], [Comment], [ReviewDate]) VALUES (N'8f016398-f157-4b89-8b3c-f5be8e68a81f', 1, N'sam', 5, N'-', CAST(N'2023-06-26T00:00:00.0000000' AS DateTime2))
GO

-- %% [markdown]
-- # [dbo].[Sellers]

-- %%
SET IDENTITY_INSERT [dbo].[Sellers] ON 
INSERT [dbo].[Sellers] ([SellerID], [LastName], [FirstName], [Patronymic], [BirthDate], [IsActive]) VALUES (1, N'Иванов', N'Иван', N'Иванович', CAST(N'1991-02-01' AS Date), 1)
INSERT [dbo].[Sellers] ([SellerID], [LastName], [FirstName], [Patronymic], [BirthDate], [IsActive]) VALUES (3, N'Си', N'Шарп', NULL, CAST(N'1998-06-05' AS Date), 1)
INSERT [dbo].[Sellers] ([SellerID], [LastName], [FirstName], [Patronymic], [BirthDate], [IsActive]) VALUES (4, N'Норбитов', N'Константин', N'Алексеевич', CAST(N'2005-09-09' AS Date), 1)
INSERT [dbo].[Sellers] ([SellerID], [LastName], [FirstName], [Patronymic], [BirthDate], [IsActive]) VALUES (5, N'Кит', N'Ольга', N'Юрьевна', CAST(N'2000-07-08' AS Date), 1)
INSERT [dbo].[Sellers] ([SellerID], [LastName], [FirstName], [Patronymic], [BirthDate], [IsActive]) VALUES (6, N'Валеев', N'Игорь', N'Петрович', CAST(N'1975-12-26' AS Date), 1)
INSERT [dbo].[Sellers] ([SellerID], [LastName], [FirstName], [Patronymic], [BirthDate], [IsActive]) VALUES (7, N'Рылов', N'Александр', NULL, CAST(N'2006-03-12' AS Date), 0)
SET IDENTITY_INSERT [dbo].[Sellers] OFF
GO

-- %% [markdown]
-- # [dbo].[Shops]

-- %%
SET IDENTITY_INSERT [dbo].[Shops] ON 
INSERT [dbo].[Shops] ([ShopID], [ShopName], [Address], [Phone]) VALUES (1, N'Орешек', N'г. Киров, ул. Володарского, 12', N'221567')
INSERT [dbo].[Shops] ([ShopID], [ShopName], [Address], [Phone]) VALUES (2, N'Арбуз', N'г. Киров, ул. Дерендяева, 39', NULL)
INSERT [dbo].[Shops] ([ShopID], [ShopName], [Address], [Phone]) VALUES (3, N'Продукты', N'г. Кирово-Чепецк, ул. Московская, 67', N'762903')
INSERT [dbo].[Shops] ([ShopID], [ShopName], [Address], [Phone]) VALUES (4, N'Продуктовый', N'г. Слободской, ул. Боровая, 62', N'196725')
SET IDENTITY_INSERT [dbo].[Shops] OFF
GO

-- %% [markdown]
-- # [dbo].[ShopSellers]

-- %%
INSERT [dbo].[ShopSellers] ([ShopID], [SellerID]) VALUES (1, 1)
INSERT [dbo].[ShopSellers] ([ShopID], [SellerID]) VALUES (1, 3)
INSERT [dbo].[ShopSellers] ([ShopID], [SellerID]) VALUES (3, 6)
INSERT [dbo].[ShopSellers] ([ShopID], [SellerID]) VALUES (4, 5)
GO

-- %% [markdown]
-- # [UQ__Receipts__C08AFDABA744E08B]

-- %%
SET ANSI_PADDING ON
GO
/****** Object:  Index [UQ__Receipts__C08AFDABA744E08B]    Script Date: 20.02.2026 18:39:43 ******/
ALTER TABLE [dbo].[Receipts] ADD UNIQUE NONCLUSTERED 
(
	[ReceiptNumber] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, SORT_IN_TEMPDB = OFF, IGNORE_DUP_KEY = OFF, ONLINE = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
GO

-- %% [markdown]
-- # [DF__Receipts__Receip__787EE5A0]

-- %%
ALTER TABLE [dbo].[Receipts] ADD  DEFAULT (newid()) FOR [ReceiptID]
GO

-- %% [markdown]
-- # [DF__Receipts__SaleDa__7B5B524B]

-- %%
ALTER TABLE [dbo].[Receipts] ADD  DEFAULT (getdate()) FOR [SaleDate]
GO

-- %% [markdown]
-- # [DF__Receipts__Paymen__7C4F7684]

-- %%
ALTER TABLE [dbo].[Receipts] ADD  DEFAULT ('Cash') FOR [PaymentType]
GO

-- %% [markdown]
-- # [DF__Reviews__ReviewI__7F2BE32F]

-- %%
ALTER TABLE [dbo].[Reviews] ADD  DEFAULT (newid()) FOR [ReviewID]
GO

-- %% [markdown]
-- # [DF__Reviews__ReviewD__02084FDA]

-- %%
ALTER TABLE [dbo].[Reviews] ADD  DEFAULT (getdate()) FOR [ReviewDate]
GO

-- %% [markdown]
-- # [DF__Sellers__IsActiv__6C190EBB]

-- %%
ALTER TABLE [dbo].[Sellers] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [FK__ContactIn__Selle__6EF57B66]

-- %%
ALTER TABLE [dbo].[ContactInfo]  WITH CHECK ADD FOREIGN KEY([SellerID])
REFERENCES [dbo].[Sellers] ([SellerID])
ON DELETE CASCADE
GO

-- %% [markdown]
-- # [FK__Receipts__Seller__7A672E12]

-- %%
ALTER TABLE [dbo].[Receipts]  WITH CHECK ADD FOREIGN KEY([SellerID])
REFERENCES [dbo].[Sellers] ([SellerID])
GO

-- %% [markdown]
-- # [FK__Receipts__ShopID__797309D9]

-- %%
ALTER TABLE [dbo].[Receipts]  WITH CHECK ADD FOREIGN KEY([ShopID])
REFERENCES [dbo].[Shops] ([ShopID])
GO

-- %% [markdown]
-- # [FK__Reviews__ShopID__00200768]

-- %%
ALTER TABLE [dbo].[Reviews]  WITH CHECK ADD FOREIGN KEY([ShopID])
REFERENCES [dbo].[Shops] ([ShopID])
ON DELETE CASCADE
GO

-- %% [markdown]
-- # [FK__ShopSelle__Selle__74AE54BC]

-- %%
ALTER TABLE [dbo].[ShopSellers]  WITH CHECK ADD FOREIGN KEY([SellerID])
REFERENCES [dbo].[Sellers] ([SellerID])
GO

-- %% [markdown]
-- # [FK__ShopSelle__ShopI__73BA3083]

-- %%
ALTER TABLE [dbo].[ShopSellers]  WITH CHECK ADD FOREIGN KEY([ShopID])
REFERENCES [dbo].[Shops] ([ShopID])
ON DELETE CASCADE
GO

-- %% [markdown]
-- # [CK__Reviews__Rating__01142BA1]

-- %%
ALTER TABLE [dbo].[Reviews]  WITH CHECK ADD CHECK  (([Rating]>=(1) AND [Rating]<=(5)))
GO

-- %% [markdown]
-- # [RetailNetwork]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [RetailNetwork] SET  READ_WRITE 
GO
